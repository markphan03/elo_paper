# %%
import pandas as pd

df = pd.read_csv("slam_elo_f1_scores.csv")

df
# Out:
#                   model  f1_elo_0.0  f1_elo_1.0  f1_elo_2.0  f1_elo_3.0  \
# 0                 gpt-4    0.897959    0.884211    0.884211    0.884211
# 1        llama2_7b-chat    0.842975    0.852459    0.852459    0.852459
# 2   mistral_7b-instruct    0.860465    0.891566    0.891566    0.891566
# 3        neural-chat_7b    0.916667    0.923077    0.933333    0.933333
# 4      openchat_7b-v3.5    0.901961    0.900000    0.900000    0.900000
# 5          orca-mini_3b    0.828829    0.807339    0.818182    0.818182
# 6              orca2_7b    0.864407    0.854701    0.854701    0.854701
# 7    stablelm-zephyr_3b    0.851485    0.862745    0.862745    0.862745
# 8        starling-lm_7b    0.857143    0.876404    0.876404    0.876404
# 9             vicuna_7b    0.867925    0.893204    0.893204    0.893204
# 10       zephyr_7b-beta    0.840909    0.804878    0.804878    0.804878
#
#     f1_elo_4.0  f1_elo_5.0  f1_elo_6.0  f1_elo_7.0  f1_elo_8.0  ...  \
# ...
